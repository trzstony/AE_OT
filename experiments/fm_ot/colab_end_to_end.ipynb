# %% [markdown]
# # FM vs OT on CelebA (Fair Comparison)\nThis notebook assumes the repo is cloned at `/content/AE_OT`. Run all cells in order.

# %%
# %cd /content/AE_OT

# %%
# %env MAX_TRAIN_IMAGES=50000\n%env MAX_TEST_IMAGES=10000\n%env DRY_RUN=0\n!bash experiments/fm_ot/run_colab_end_to_end.sh

# %%
# !python - <<'PY'\nfrom pathlib import Path\nimport pandas as pd\nsummary = Path('/content/AE_OT/experiments/fm_ot/runs/celeba_fm_vs_ot/summary.csv')\nif summary.exists():\n    print(pd.read_csv(summary).head())\nelse:\n    print('summary.csv not found yet')\nPY
